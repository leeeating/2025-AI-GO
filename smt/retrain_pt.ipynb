# %%
import os
import pandas as pd
import numpy as np

def creat_df(file_name_list):
    mg_df = pd.DataFrame()

    for file in file_name_list:
        name = f"../{file}"
        col = name.split('/')[-1].split('.csv')[0]
        df_tmp = pd.read_csv(name)
        mg_df['ID'] = df_tmp['ID'][:25108]
        mg_df[col] = df_tmp['飆股'][:25108]
    mg_df['sum'] = mg_df.iloc[: ,1:].mean(axis=1)
    mg_df['ID2'] = mg_df['ID'][:25108]
    return mg_df

# %%
model_list = [
    'smt/smt_folder/0.9291_0.7443_141_146.csv',
    'smt/smt_folder/com_v1_opt.csv',
    'smt/smt_folder/com_v1.csv',
    'smt/smt_folder/enemble_v1_all_dis.csv',
    'smt/smt_folder/feat_v4_t500_c5_cb.csv',
    'smt/smt_folder/feat_v4_t500_c5_op22.csv',
    'smt/smt_folder/fv4_105_0.830_0.765_162.csv',
    'smt/smt_folder/fv4_105_0.884_0.779_159.csv',
    'smt/smt_folder/fv4_419_0.827_0.782_185.csv',
    'smt/smt_folder/fv4_419_ensemble_153.csv',
    'smt/smt_folder/fv4_419_op22_re158.csv',
    'smt/smt_folder/lgbm_model_v2_smt.csv',
    'smt/smt_folder/ptsmt_9203_7962_148157.csv',
    'smt/smt_folder/submission_3k-rank6.csv',
    'smt/smt_folder/test_prec.csv',
    'smt/test_smt_dolfer/ptsmt_9203_7962_148157.csv',
    'smt/test_smt_dolfer/sudo1_5.csv',
]


pt_df = creat_df(model_list)

# %%
pt_df.sort_values(by=['sudo1_5','sum'], ascending=False).reset_index(drop=True)
# Out:
#              ID  0.9291_0.7443_141_146  com_v1_opt  com_v1  \
# 0      PU-17378                      1           1       1
# 1      PU-12519                      0           0       0
# 2      PU-12155                      1           0       0
# 3      PU-15012                      0           0       0
# 4       PU-4160                      0           0       0
# ...         ...                    ...         ...     ...
# 25103  PU-25104                      0           0       0
# 25104  PU-25105                      0           0       0
# 25105  PU-25106                      0           0       0
# 25106  PU-25107                      0           0       0
# 25107  PU-25108                      0           0       0
#
#        enemble_v1_all_dis  feat_v4_t500_c5_cb  feat_v4_t500_c5_op22  \
# 0                       1                   1                     1
# 1                       0                   1                     0
# ...
